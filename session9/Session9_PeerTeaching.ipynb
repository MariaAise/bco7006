# %% [markdown]
# # Session 9 — Peer Teaching (25 min)
# **Groups of 4** · 12 min prepare · 13 min present (3 min each)
#
# ## Topics
#
# ### Topic A — Broadcasting
# Explain the rule. Show one case that works, one that fails. Why is broadcasting useful?
#
# ### Topic B — Fancy indexing
# Show indexing with a list of integers. Then with a boolean mask. When is each natural?
#
# ### Topic C — `np.where` and conditional assignment
# Show how to replace values conditionally without a loop. Bonus: nested `np.where`.
#
# ### Topic D — The `axis` parameter
# Why does `arr.sum(axis=0)` give column sums (not row sums)? Use a diagram or labelled example.
#
# ## Requirements
# - 1-line definition
# - Live demo
# - Common mistake
# - Business use case

# %%
import numpy as np
# Working space
