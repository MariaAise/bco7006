# %% [markdown]
# # Session 8 — Mini Project (30 min)
# # Build the Marketing Dashboard Data
#
# ## Scenario
# The marketing manager wants a dashboard. You'll produce the SOURCE DATA tables for it. Use `clean_merged.csv` from the pair programming activity (or rebuild it from raw files if you haven't completed that).
#
# ## Deliverables (one notebook per pair)
# Produce these 4 tables, each clearly labelled, and save each as a CSV.
#
# ### Table 1 — Category performance
# For each `category`: number of transactions, total revenue, average transaction value. Sort by total revenue descending.
#
# ### Table 2 — Monthly trend
# A wide table: rows = months, columns = categories, values = total revenue per month per category.
#
# ### Table 3 — Customer cohorts
# Bucket customers into age groups: under 30, 30–44, 45–59, 60+. For each group: number of customers, total spend, average spend per transaction.
#
# (Hint: use `pd.cut()` with `bins=[0, 30, 45, 60, 200]` and `labels=['<30', '30-44', '45-59', '60+']`)
#
# ### Table 4 — Country × category heatmap data
# Pivot: rows = country, columns = category, values = total amount.

# %%
import pandas as pd
df = pd.read_csv('clean_merged.csv', parse_dates=['txn_date', 'signup_date'])
df.head()

# %% [markdown]
# ## Table 1

# %% [markdown]
# ## Table 2

# %% [markdown]
# ## Table 3

# %% [markdown]
# ## Table 4

# %% [markdown]
# ## Wrap up
# Save each as `table1.csv`, `table2.csv`, etc. Be ready to show one of your tables and explain ONE insight you can read from it.
