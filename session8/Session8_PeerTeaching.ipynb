# %% [markdown]
# # Session 8 — Peer Teaching Activity (25 min)
# **Groups of 4** · 12 min prepare · 13 min present (3 min each)
#
# ## Topics
#
# ### Topic A — Merge join types
# Demonstrate `inner`, `left`, `right`, `outer` joins on a tiny example. When would each be the right choice?
#
# ### Topic B — Long vs Wide format
# Show the same data in both shapes. Which is better for plotting? For human reading? For storage?
#
# ### Topic C — `groupby` vs `pivot_table`
# They can produce similar output. When is each more natural? Show a case where one is much shorter than the other.
#
# ### Topic D — Datetime resampling
# Show `.resample('M').sum()` vs `.groupby(df['col'].dt.to_period('M')).sum()`. When is `resample` available, and when isn't it?
#
# ## Each presentation must include
# 1. A 1-line definition
# 2. A live code demo (use any of `customers.csv`, `transactions.csv`, or a tiny invented DataFrame)
# 3. One real business use case

# %%
# Working space
import pandas as pd
import numpy as np
