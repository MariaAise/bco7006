# %% [markdown]
# # Session 10 — Mini Project (30 min)
# # Pure NumPy Analytics — No AI Allowed
#
# **Solo work.** No ChatGPT, no Copilot, no Stack Overflow. You can use the lecture notebook and your earlier exercises.
#
# ## Scenario
# You're evaluating two investment strategies on the stock data:
# - **Strategy A:** equal weights across all 5 stocks
# - **Strategy B:** weights inversely proportional to each stock's volatility (lower vol = higher weight)
#
# Compute and compare them.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('stock_prices.csv')
tickers = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'META']
prices = df[tickers].to_numpy()
print("Shape:", prices.shape)

# %% [markdown]
# ## Task 1 — Daily returns
# Compute the daily return matrix (one fewer row than prices).

# %% [markdown]
# ## Task 2 — Per-stock annualised volatility

# %% [markdown]
# ## Task 3 — Strategy weights
# - `weights_A` = equal across all 5 stocks (each 0.2)
# - `weights_B` = inversely proportional to volatility, normalised to sum to 1.0
#   Hint: `inv_vol = 1 / vol`, then `weights_B = inv_vol / inv_vol.sum()`

# %% [markdown]
# ## Task 4 — Portfolio daily returns for each strategy

# %% [markdown]
# ## Task 5 — Compare
# Print for each strategy:
# - Mean daily return
# - Annualised return (mean × 252)
# - Annualised volatility (std × √252)
# - Sharpe ratio (annual_return / annual_vol)

# %% [markdown]
# ## Task 6 — Plot
# On a single chart, plot cumulative returns of both strategies over time.
# Hint: cumulative_return = `(1 + portfolio_returns).cumprod() - 1`

# %% [markdown]
# ## Wrap up
# Which strategy performed better on Sharpe? Is that what you expected? Be ready to explain in 1 sentence.
