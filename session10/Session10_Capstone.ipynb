# %% [markdown]
# # Session 10 — Capstone Activity
# # AI-Assisted Coding + Critical Review
# **Duration:** 60 min · **Pairs**
#
# ## Why this activity exists
# You will use ChatGPT (or Claude, Copilot — any LLM) in your career. The skill that separates a good analyst from a dangerous one is **the ability to read AI-generated code critically**.
#
# LLMs confidently produce code that:
# - Uses deprecated functions
# - Has off-by-one errors
# - Computes the wrong thing while looking right
# - Ignores edge cases (NaN, empty arrays, division by zero)
# - Hallucinates function names
#
# Your job is to find these issues and fix them. The deliverable is **not** working code — it's a documented critique.
#
# ## The brief
# You are given the dataset `stock_prices.csv` (252 days, 5 stocks).
#
# Build an **investment analysis script** that:
# 1. Computes daily returns
# 2. Reports annualised return and volatility for each stock
# 3. Identifies the **best Sharpe ratio** stock (assume risk-free rate = 0)
#    Sharpe = mean_return / std_return × √252
# 4. Plots the cumulative return of an equal-weighted portfolio
# 5. Saves a summary CSV
#
# ## Process (60 min)
#
# ### Step 1 (10 min) — Write your prompt
# Working with your pair, design a single well-crafted prompt that asks the LLM to write this script. Paste your final prompt below.

# %% [markdown]
# **Your prompt:**
#
# ```
# [paste here]
# ```

# %% [markdown]
# ### Step 2 (10 min) — Get the AI's response
# Run the prompt against your chosen LLM. Paste the AI's response **exactly as generated**, unmodified, in the cell below. Do not run it yet.

# %%
# AI-generated code — DO NOT MODIFY YET
# Paste here exactly as the LLM gave it to you

# %% [markdown]
# ### Step 3 (20 min) — Critique
# Now examine the code line by line. For EACH issue you find, document it in the table below.
#
# | # | Issue | Where (cell/line) | Why it's a problem | Your fix |
# |---|---|---|---|---|
# | 1 | | | | |
# | 2 | | | | |
# | 3 | | | | |
# | 4 | | | | |
#
# **Required: find at least 2 real issues.** Things to look for:
# - Does the daily return formula match what you'd write yourself?
# - Are NaN values handled? What if the data had any?
# - Does the Sharpe ratio annualise correctly?
# - Are the axes correct in any aggregation (axis=0 vs axis=1)?
# - Are imports complete?
# - Are file paths assumed?
# - Are the column names hardcoded vs derived?
# - Does the plot actually display?
# - Is the summary CSV index sensible?

# %% [markdown]
# ### Step 4 (15 min) — Fix and re-run
# Below, paste the **corrected** version with your fixes applied. Comment each fix with `# FIX:` so the lecturer can see what you changed.

# %%
# CORRECTED code

# %% [markdown]
# ### Step 5 (5 min) — Reflection
# Answer briefly:
#
# 1. **How much of the AI's original code did you keep?** (most / half / little)
#
# 2. **What was the AI's biggest weakness on this task?**
#
# 3. **For what kind of coding work would you trust AI MORE?** For what kind LESS?
#
# 4. **If a junior analyst on your team submitted the AI's original code as their work, what feedback would you give them?**

# %% [markdown]
# ## Submission
# - Save this notebook as `Session10_Capstone_[your-names].ipynb`
# - Submit via VU Collaborate
