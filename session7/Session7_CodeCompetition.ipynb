# %% [markdown]
# # Session 7 — 20-Minute Code Competition
# # Speed Challenge: Selection, Filtering & Sorting
#
# **Rules:**
# - Work in teams of 3-4
# - 8 tasks. **First team to finish all 8 correctly wins.**
# - One person types at a time, rotate every task
# - You may discuss within your team only
# - Each task = one line (or one chain) — no helper functions needed
#
# ⏱ Timer starts when the instructor says GO.

# %%
# Setup — run me first
import pandas as pd
df = pd.read_csv('sales_data.csv')
df.head(2)

# %% [markdown]
# ## Task 1 — How many rows have revenue greater than the mean revenue?

# %% [markdown]
# ## Task 2 — Show only the row with the highest revenue (use `.idxmax()`)

# %% [markdown]
# ## Task 3 — How many unique products are there? How many unique sales reps?

# %% [markdown]
# ## Task 4 — Show all sales by Alice or Bob in the South region, sorted by revenue descending

# %% [markdown]
# ## Task 5 — What is the average customer rating? (NaN values should be ignored — most pandas functions do this automatically)

# %% [markdown]
# ## Task 6 — Show the bottom 5 sales (lowest revenue) using a method chain

# %% [markdown]
# ## Task 7 — Find rows where `units` is greater than 40 AND `unit_price` is less than $50

# %% [markdown]
# ## Task 8 — Final challenge
# Using a single chained expression, find the **3 highest-revenue sales** for each region. Return only `region`, `product`, `sales_rep`, `revenue`.
#
# **Hint:** sort, then `.groupby('region').head(3)`

# %% [markdown]
# ## Done?
# 🙋 Raise your hand. Instructor will verify your answers.
