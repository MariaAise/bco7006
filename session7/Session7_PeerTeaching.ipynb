# %% [markdown]
# # Session 7 — Peer Teaching Activity
# **Duration:** 35 min · **Groups of 4**
#
# ## How it works
# - Each group is assigned ONE of the 4 topics below
# - **15 min:** prepare a 4-minute explanation with a live code demo
# - **20 min:** each group teaches their topic to the class (4 min teach + 1 min Q&A)
#
# ## Why peer teaching?
# You learn 5x more from teaching than from listening. Your explanation must include:
# 1. A 1-sentence definition
# 2. A code example you actually run
# 3. One common mistake or "gotcha"
# 4. One real business scenario where this is useful

# %% [markdown]
# ## Topic 1 — `.loc` vs `.iloc`
#
# When would you use one over the other? What happens if you mix them up?
#
# **Starter code:**

# %%
import pandas as pd
df = pd.read_csv('sales_data.csv')

# Show .loc, then .iloc, then a case where they give different results

# %% [markdown]
# ## Topic 2 — Boolean filtering & the `&`, `|`, `~` operators
#
# Why can't we use `and`, `or`, `not` like normal Python? Why are parentheses required?
#
# **Starter code:**

# %%
import pandas as pd
df = pd.read_csv('sales_data.csv')

# Try without parentheses, then with. Show the error.
# Show the difference between & and `and` on a Series.

# %% [markdown]
# ## Topic 3 — The `SettingWithCopyWarning`
#
# When does this warning appear? Why does it matter? How do you fix it?
#
# **Starter code:**

# %%
import pandas as pd
df = pd.read_csv('sales_data.csv')

# Reproduce the warning by chained assignment
# Then show the .loc-based fix

# %% [markdown]
# ## Topic 4 — `.query()` — the SQL-like alternative
#
# When is `df.query("revenue > 5000")` better than `df[df['revenue'] > 5000]`? When is it worse?
#
# **Starter code:**

# %%
import pandas as pd
df = pd.read_csv('sales_data.csv')

# Show a .query() example, then the bracket equivalent
# Show when .query() shines (column names with spaces, long conditions)

# %% [markdown]
# ## After all groups have presented (5 min)
# **Class discussion:** which technique are you most likely to use this week? Why?
