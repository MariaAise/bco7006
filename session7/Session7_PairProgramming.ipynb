# %% [markdown]
# # Session 7 — Pair Programming Activity
# # Sales Data Exploration
# **Duration:** 40 min · **Pairs**
#
# ## How to work
# - **Driver** types, **Navigator** reviews and suggests. **Swap roles after each task.**
# - Discuss before you type. If you disagree, run both versions and compare.
# - Don't peek at the solution notebook until you're stuck for >5 min.
#
# ## Scenario
# You've just joined the analytics team at a wholesale company. Your manager dumps `sales_data.csv` on your desk and says *"see what's in there"*. There are 8 tasks below — work through them in order.

# %% [markdown]
# ## Task 0 — Setup
# Load the data and confirm it loaded correctly.

# %%
# Your code: import pandas, load the file, show first 5 rows

# %% [markdown]
# ## Task 1 — Inspect
# Print:
# - the shape of the dataset
# - the column names
# - the data types
# - summary statistics for numeric columns
#
# **Discuss with your pair:** Which columns are numeric? Are any data types surprising?

# %%
# Your code here

# %% [markdown]
# ## Task 2 — Select by position (`.iloc`)
# 1. Show row 10 only
# 2. Show the first 3 rows and the first 4 columns
# 3. Show the LAST 5 rows using `.iloc` (hint: negative indexing)

# %%
# Your code here

# %% [markdown]
# ## Task 3 — Select by label (`.loc`)
# 1. Use `.loc` to show rows 0 through 4 (inclusive) for the columns `region`, `product`, `revenue`
# 2. **Comprehension check:** how many rows did task 3.1 return? Compare with `df.iloc[0:4]` — why are they different?

# %%
# Your code here

# %% [markdown]
# ## Task 4 — Single-condition filter
# Find all rows where `revenue` is greater than $7000. How many are there?

# %%
# Your code here

# %% [markdown]
# ## Task 5 — Compound filter
# Find sales that meet ALL of:
# - Region is `'East'` OR `'West'`
# - Units sold is at least 20
# - Customer rating is 4 or 5
#
# Show only the columns `date`, `region`, `product`, `units`, `customer_rating`.
#
# **Hint:** use `.isin()` for the region check. Don't forget parentheses around each condition.

# %%
# Your code here

# %% [markdown]
# ## Task 6 — Sort
# 1. Sort by `revenue` descending. Show the top 5.
# 2. Sort by `region` ascending, then `revenue` descending within each region. Show top 10.

# %%
# Your code here

# %% [markdown]
# ## Task 7 — Method chain (the business question)
# Answer this in **a single chained expression**:
#
# > *"What were the 3 highest-revenue sales for Widget A, showing only date, region, sales_rep, and revenue?"*

# %%
# Your code here — one chain: filter → select cols → sort → head(3)

# %% [markdown]
# ## Task 8 — Stretch (if you finish early)
# Each rep's best sale: for each sales rep, what was their single highest-revenue sale?
#
# **Hint:** sort by revenue descending, then use `.drop_duplicates(subset='sales_rep', keep='first')`.

# %%
# Your code here

# %% [markdown]
# ## Wrap up — discuss with your pair (5 min)
# 1. Which task was hardest? Why?
# 2. When would you use `.loc` vs `.iloc` in real work?
# 3. What's one pandas function you want to know better after today?
#
# Be ready to share with the class.
